# %%
# Import all the things
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly.figure_factory as ff
import waterfall_chart
import altair as alt
from vega_datasets import data as vega_data
import plotly.plotly as py
import plotly.graph_objs as go
from itertools import product
import colorlover as cl


# General settings
pd.options.display.max_rows = 10
pd.options.display.max_seq_items = 200

static_dir = "slides/static/"

# %%
# %store -r df

# %%
mydf = df[
    (df['protestant_pct'] >0) |  (df['republican_shift'] !=0 )
]

from altair import Chart, Color, Scale, Opacity

counties = alt.topo_feature(vega_data.us_10m.url, 'counties')

states = alt.topo_feature(vega_data.us_10m.url, 'states')

outlines = alt.Chart(states).mark_geoshape(
    stroke='black'
).project('albersUsa')
    
shift = alt.Chart(counties).mark_geoshape().encode(
 Color('republican_shift:Q', scale=Scale(domain=[0, 23],
                      range=['white', 'red'])),

).transform_lookup(
    lookup='id',
    from_=alt.LookupData(mydf, 'id', ['republican_shift'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)

shift + outlines

# %%
mydf = df[
    (df['protestant_pct'] >0) |  (df['republican_shift'] >0) 
]
describe
from altair import Chart, Color, Scale, Opacity

counties = alt.topo_feature(vega_data.us_10m.url, 'counties')

states = alt.topo_feature(vega_data.us_10m.url, 'states')

outlines = alt.Chart(states).mark_geoshape(
    stroke='black'
).project('albersUsa')
    
protestants = alt.Chart(counties).mark_geoshape().encode(
    Color('protestant_pct:Q', scale=Scale(domain=[0, 100],
                      range=['white', 'blue'])),
    Opacity('protestant_pct:Q', scale=Scale(domain=[0, 100],
                      range=[0, 1])),
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(mydf, 'id', ['protestant_pct'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)

protestants + outlines

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

df = df[(df.state_abbr != 'UT') & (df.state_abbr != 'ID')]


data = [go.Scatter3d(
    x=df[df['Rural_urban_continuum_code_2013']==value]['TOTRATE'],
    y=df[df['Rural_urban_continuum_code_2013']==value]['High School Only or Less, 2012-2016'],
    z=df[df['Rural_urban_continuum_code_2013']==value]['republican_shift'],
    text=df['GEO.display-label'],
    mode='markers',
    marker=dict(
        size=4,
        color=value,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8,
    )
) for value in sorted(df['Rural_urban_continuum_code_2013'].unique())]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    ),
   scene = dict(
    aspectmode='cube',
    xaxis = dict(title='All Religious Adherents Rate'),
    yaxis = dict(title='High School Only or Less, 2012-2016'),
    zaxis = dict(title='Republican Shift'),),
    
    legend=dict(x=-.1, y=1.2)
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
df = df[(df.state_abbr != 'UT') & (df.state_abbr != 'ID')]


data = [go.Scatter3d(
    x=df[df['Rural_urban_continuum_code_2013']==value]['2013 Urban Influence Code'],
    y=df[df['Rural_urban_continuum_code_2013']==value]['High School Only or Less, 2012-2016'],
    z=df[df['Rural_urban_continuum_code_2013']==value]['republican_shift'],
    text=df[df['Rural_urban_continuum_code_2013']==value]['GEO.display-label'],
    mode='markers',
    marker=dict(
        size=4,
        color=value,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8,
    )
) for value in sorted(df['Rural_urban_continuum_code_2013'].unique())]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    ),
   scene = dict(
    xaxis = dict(title='All Religious Adherents Rate'),
    yaxis = dict(title='High School Only or Less, 2012-2016'),
    zaxis = dict(title='Republican Shift'),),
    
    legend=dict(x=-.1, y=1.2),
)
fig = go.Figure(data=data, layout=layout)
plotly.offline.plot(fig)
